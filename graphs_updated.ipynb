# %%
import pandas as pd

# %%
my_dict={'nbr_stars':[12,12,12,12,12],
        'to_BH':[55,55,55,55,55],
        'life_span':[8,8,8,8,8],
        'spawn_rate':[0.024,0.024,0.024,0.024,0.024],
        'nombre de TN 1':[5,3,4,6,3],
        'temps(milliard d\'anees)':[1,2,3,4,5],
        'nombre de TN 2':[5,6,6,4,4]}

# %%
df=pd.DataFrame(data=my_dict)

# %%
df.plot.line(figsize=(10,5),title='nombre des trous noirs',x='temps(milliard d\'anees)',y=['nombre de TN 1','nombre de TN 2'],use_index='True')
# Out:
# <AxesSubplot:title={'center':'nombre des trous noirs'}, xlabel="temps(milliard d'anees)">

# %%
my_dict2={'nombre de TN 1':[5,3,4,6,3],
          'nombre de TN 3':[3,2,3,3,3],
         'temps(milliard d\'anees)':[1,2,3,4,5]}

# %%
df=pd.DataFrame(data=my_dict2)
df.plot.line(figsize=(10,5),title='Nombre des trous noirs',x='temps(milliard d\'anees)',y=['nombre de TN 1','nombre de TN 3'],use_index='True')
# Out:
# <AxesSubplot:title={'center':'Nombre des trous noirs'}, xlabel="temps(milliard d'anees)">

# %%
my_dict3={'nombre de TN 1':[5,3,4,6,3],
         'nombre de TN 4':[2,3,4,0,2],
         'temps(milliard d\'anees)':[1,2,3,4,5]}

# %%
df=pd.DataFrame(data=my_dict3)
df.plot.line(figsize=(10,5),title='Nombre des trous noirs',x='temps(milliard d\'anees)',y=['nombre de TN 1','nombre de TN 4'],use_index='True')
# Out:
# <AxesSubplot:title={'center':'Nombre des trous noirs'}, xlabel="temps(milliard d'anees)">

# %%
my_dict4={'nombre de TN 1':[5,3,4,6,3],
          'nombre de TN 5':[3,0,2,2,0],
         'temps(milliard d\'anees)':[1,2,3,4,5]}

# %%
df=pd.DataFrame(data=my_dict4)
df.plot.line(figsize=(10,5),title='Nombre des trous noirs',x='temps(milliard d\'anees)',y=['nombre de TN 1','nombre de TN 5'],use_index='True')
# Out:
# <AxesSubplot:title={'center':'Nombre des trous noirs'}, xlabel="temps(milliard d'anees)">

# %%
my_dict5={'nombre de TN 1':[5,3,4,6,3],
          'nombre de TN 6':[3,4,3,4,5],
         'temps(milliard d\'anees)':[1,2,3,4,5]}

# %%
df=pd.DataFrame(data=my_dict5)
df.plot.line(figsize=(10,5),title='Nombre des trous noirs',x='temps(milliard d\'anees)',y=['nombre de TN 1','nombre de TN 6'],use_index='True')
# Out:
# <AxesSubplot:title={'center':'Nombre des trous noirs'}, xlabel="temps(milliard d'anees)">
