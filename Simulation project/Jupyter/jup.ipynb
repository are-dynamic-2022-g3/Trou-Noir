# %%
import json
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd

# %%
with open('finalData.json', 'r') as f:
  data = json.load(f)

# %%
#plt.plot(data['data']['1']['nb_blackhole'])
#plt.plot(data['data']['2']['nb_blackhole'])
#plt.plot(data['data']['3']['nb_blackhole'])
#plt.plot(data['data']['4']['nb_blackhole'])
#plt.plot(data['data']['5']['nb_blackhole'])

s = [0] * len(data['data']['1']['nb_stars'])
for i in range(6):
  for j in range(len(data['data'][str(i+1)]['nb_stars'])):
    s[j] += data['data'][str(i+1)]['nb_stars'][j] / 6
plt.plot(s)
